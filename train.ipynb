# %%
import numpy as np
import configparser
from tensorflow import keras
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, core, Dropout, concatenate, BatchNormalization,Activation
from keras.callbacks import ModelCheckpoint,TensorBoard

from helpers import load_hdf5
# Out:
# Using TensorFlow backend.

# %%
config = configparser.RawConfigParser()
config.read('configuration.txt')

#train data
train_imgs = config.get('data paths', 'train_imgs')
train_gt = config.get('data paths', 'train_gt')

#training settings
N_epochs = int(config.get('training settings', 'N_epochs'))
batch_size = int(config.get('training settings', 'batch_size'))

#patch properties
patch_height = int(config.get('data attributes','patch_height'))
patch_width = int(config.get('data attributes','patch_width'))
patch_num = int(config.get('data attributes','patch_num'))

# %%
def masks_reshape(masks):
    
    im_h = masks.shape[1]
    im_w = masks.shape[2]
    
    masks = np.reshape(masks,(masks.shape[0],im_h*im_w))
    new_masks = np.empty((masks.shape[0],im_h*im_w,2), dtype = 'float16')
    for i in range(masks.shape[0]):
        for j in range(im_h*im_w):
            if  masks[i,j] == 1:
                new_masks[i,j,0]=1
                new_masks[i,j,1]=0
            
            else:
                new_masks[i,j,0]=0
                new_masks[i,j,1]=1
                
    return new_masks

# %%
def getShallowUnet(patch_height,patch_width,n_ch):
    #
    inputs = Input((patch_height, patch_width,n_ch))
    #
    conv1 = Conv2D(32, (3, 3), padding="same", activation="relu")(inputs)
    conv1 = Dropout(0.2)(conv1)
    conv1 = Conv2D(32, (3, 3), padding="same", activation="relu")(conv1)
    print(conv1.shape)
    #
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    print(pool1.shape)
    #
    conv2 = Conv2D(64, (3, 3), padding="same", activation="relu")(pool1)
    conv2 = Dropout(0.2)(conv2)
    conv2 = Conv2D(64, (3, 3), padding="same", activation="relu")(conv2)
    print(conv2.shape)
    #
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    print(pool2.shape)
    #
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Dropout(0.2)(conv3)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    print(conv3.shape)
    #
    up1 = concatenate([UpSampling2D(size=(2, 2))(conv3), conv2], axis=-1)
    print(up1.shape)
    #
    conv4 = Conv2D(64, (3, 3), activation='relu', padding='same')(up1)
    conv4 = Dropout(0.2)(conv4)
    conv4 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv4)
    print(conv4.shape)
    #
    up2 = concatenate([UpSampling2D(size=(2, 2))(conv4), conv1], axis=-1)
    print(up2.shape)
    #
    conv5 = Conv2D(32, (3, 3), activation='relu', padding='same')(up2)
    conv5 = Dropout(0.2)(conv5)
    conv5 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv5)
    print(conv5.shape)
    #
    conv6 = Conv2D(2, (1, 1), activation='relu', padding='same')(conv5)
    print(conv6.shape)
    conv6 = core.Reshape((2,patch_height*patch_width))(conv6)
    print(conv6.shape)
    conv6 = core.Permute((2,1))(conv6)
    print(conv6.shape)
    #
    conv7 = core.Activation('softmax')(conv6)
    print(conv7.shape)

    model = Model(inputs=inputs, outputs=conv7)

    model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    model.summary()

    return model

# %%
#Unet with batch normalization
def getShallowUnet2(patch_height,patch_width,n_ch):
    #
    inputs = Input((patch_height, patch_width,n_ch))
    #
    conv1 = Conv2D(32, (3, 3), padding="same")(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    conv1 = Dropout(0.2)(conv1)
    
    conv1 = Conv2D(32, (3, 3), padding="same")(conv1)
    conv1 = BatchNormalization()(conv1)
    conv1 = Activation('relu')(conv1)
    print(conv1.shape)
    #
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    print(pool1.shape)
    #
    conv2 = Conv2D(64, (3, 3), padding="same")(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    conv2 = Dropout(0.2)(conv2)
    
    conv2 = Conv2D(64, (3, 3), padding="same")(conv2)
    conv2 = BatchNormalization()(conv2)
    conv2 = Activation('relu')(conv2)
    print(conv2.shape)
    #
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    print(pool2.shape)
    #
    conv3 = Conv2D(128, (3, 3), padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    conv3 = Dropout(0.2)(conv3)
    
    conv3 = Conv2D(128, (3, 3), padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    conv3 = Activation('relu')(conv3)
    print(conv3.shape)
    #
    up1 = concatenate([UpSampling2D(size=(2, 2))(conv3), conv2], axis=-1)
    print(up1.shape)
    #
    conv4 = Conv2D(64, (3, 3),padding='same')(up1)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    conv4 = Dropout(0.2)(conv4)
    
    conv4 = Conv2D(64, (3, 3), padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    conv4 = Activation('relu')(conv4)
    print(conv4.shape)
    #
    up2 = concatenate([UpSampling2D(size=(2, 2))(conv4), conv1], axis=-1)
    print(up2.shape)
    #
    conv5 = Conv2D(32, (3, 3), padding='same')(up2)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)
    conv5 = Dropout(0.2)(conv5)
    
    conv5 = Conv2D(32, (3, 3), padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    conv5 = Activation('relu')(conv5)
    print(conv5.shape)
    #
    conv6 = Conv2D(2, (1, 1), activation='relu', padding='same')(conv5)
    print(conv6.shape)
    conv6 = core.Reshape((2,patch_height*patch_width))(conv6)
    print(conv6.shape)
    conv6 = core.Permute((2,1))(conv6)
    print(conv6.shape)
    #
    conv7 = core.Activation('softmax')(conv6)
    print(conv7.shape)

    model = Model(inputs=inputs, outputs=conv7)

    model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    model.summary()

    return model

# %%
model = getShallowUnet2(patch_width, patch_height, 1)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0819 13:23:29.342400 47709276951424 deprecation_wrapper.py:118] From /software/tensorflow/2.0.0b/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0819 13:23:29.367875 47709276951424 deprecation_wrapper.py:118] From /software/tensorflow/2.0.0b/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0819 13:23:29.373198 47709276951424 deprecation_wrapper.py:118] From /software/tensorflow/2.0.0b/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0819 13:23:29.403563 47709276951424 deprecation_wrapper.py:118] From /software/tensorflow/2.0.0b/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0819 13:23:29.405791 47709276951424 deprecation_wrapper.py:118] From /software/tensorflow/2.0.0b/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0819 13:23:32.327746 47709276951424 deprecation_wrapper.py:118] From /software/tensorflow/2.0.0b/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0819 13:23:32.408239 47709276951424 deprecation.py:506] From /software/tensorflow/2.0.0b/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0819 13:23:32.519795 47709276951424 deprecation_wrapper.py:118] From /software/tensorflow/2.0.0b/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# (?, 32, 32, 32)
# (?, 16, 16, 32)
# W0819 13:23:32.954913 47709276951424 deprecation_wrapper.py:118] From /software/tensorflow/2.0.0b/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
# (?, 16, 16, 64)
# (?, 8, 8, 64)
# (?, 8, 8, 128)
# (?, 16, 16, 192)
# (?, 16, 16, 64)
# (?, 32, 32, 96)
# W0819 13:23:33.486143 47709276951424 deprecation_wrapper.py:118] From /software/tensorflow/2.0.0b/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# (?, 32, 32, 32)
# (?, 32, 32, 2)
# (?, 2, 1024)
# (?, 1024, 2)
# (?, 1024, 2)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 32)   9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 64)   36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 64)     0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 128)    73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 128)    512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 128)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 128)    0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 128)    147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 128)    512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 128)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 192)  0           up_sampling2d_1[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 64)   110656      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 64)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   36928       dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 64)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 96)   0           up_sampling2d_2[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 32)   27680       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 32)   128         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 32)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32, 32, 32)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 32)   9248        dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 32)   128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 2)    66          activation_10[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 2, 1024)      0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 1024, 2)      0           reshape_1[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 1024, 2)      0           permute_1[0][0]
# ==================================================================================================
# Total params: 473,570
# Trainable params: 472,290
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
X_train = load_hdf5(train_imgs)
X_train = X_train.reshape((X_train.shape[0], patch_height, patch_width, 1))

Y_train = load_hdf5(train_gt)
Y_train = Y_train.reshape((Y_train.shape[0], patch_height, patch_width,1))
Y_train = masks_reshape(Y_train)

# %%
X_train.shape
# Out:
# (38000, 32, 32, 1)

# %%
#train
model = getShallowUnet2(patch_width, patch_height,1)
json_string = model.to_json()
open('model.json', 'w').write(json_string)
checkpointer = ModelCheckpoint('bestWeights1.h5', verbose=1, monitor='val_loss', mode='auto', save_best_only=True) 
tbCallback = TensorBoard(log_dir='./logs', histogram_freq=0, write_graph=True, write_images=True)

model.fit(X_train, Y_train, epochs = N_epochs, batch_size = batch_size, verbose=2, shuffle=True, validation_split=0.15, callbacks=[checkpointer,tbCallback])
model.save_weights('lastWeights1.h5', overwrite=True)
# Out:
# (?, 32, 32, 32)
# (?, 16, 16, 32)
# (?, 16, 16, 64)
# (?, 8, 8, 64)
# (?, 8, 8, 128)
# (?, 16, 16, 192)
# (?, 16, 16, 64)
# (?, 32, 32, 96)
# (?, 32, 32, 32)
# (?, 32, 32, 2)
# (?, 2, 1024)
# (?, 1024, 2)
# (?, 1024, 2)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 32, 32, 1)    0
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 32)   320         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 32)   128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 32)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 32, 32, 32)   0           activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 32)   9248        dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 32)   128         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 32)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 32)   0           activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 64)   18496       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 16, 16, 64)   0           activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 64)   36928       dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 8, 8, 64)     0           activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 128)    73856       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 128)    512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 8, 8, 128)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 8, 8, 128)    0           activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 8, 8, 128)    147584      dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 8, 8, 128)    512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 128)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 16, 16, 128)  0           activation_28[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 192)  0           up_sampling2d_5[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 64)   110656      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 16, 16, 64)   0           activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 64)   36928       dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 32, 32, 64)   0           activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 96)   0           up_sampling2d_6[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 32)   27680       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 32)   128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 32)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 32, 32, 32)   0           activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 32)   9248        dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 32)   128         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 32)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 2)    66          activation_32[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 2, 1024)      0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 1024, 2)      0           reshape_3[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 1024, 2)      0           permute_3[0][0]
# ==================================================================================================
# Total params: 473,570
# Trainable params: 472,290
# Non-trainable params: 1,280
# __________________________________________________________________________________________________
# Train on 32300 samples, validate on 5700 samples
# Epoch 1/60
#  - 58s - loss: 0.3598 - acc: 0.8397 - val_loss: 0.2702 - val_acc: 0.8661
#
# Epoch 00001: val_loss improved from inf to 0.27019, saving model to bestWeights12.h5
# Epoch 2/60
#  - 56s - loss: 0.3000 - acc: 0.8549 - val_loss: 0.2622 - val_acc: 0.8755
#
# Epoch 00002: val_loss improved from 0.27019 to 0.26220, saving model to bestWeights12.h5
# Epoch 3/60
#  - 57s - loss: 0.2867 - acc: 0.8608 - val_loss: 0.2436 - val_acc: 0.8805
#
# Epoch 00003: val_loss improved from 0.26220 to 0.24357, saving model to bestWeights12.h5
# Epoch 4/60
#  - 57s - loss: 0.2799 - acc: 0.8643 - val_loss: 0.2446 - val_acc: 0.8819
#
# Epoch 00004: val_loss did not improve from 0.24357
# Epoch 5/60
#  - 57s - loss: 0.2756 - acc: 0.8663 - val_loss: 0.2373 - val_acc: 0.8844
#
# Epoch 00005: val_loss improved from 0.24357 to 0.23735, saving model to bestWeights12.h5
# Epoch 6/60
#  - 57s - loss: 0.2729 - acc: 0.8679 - val_loss: 0.2398 - val_acc: 0.8860
#
# Epoch 00006: val_loss did not improve from 0.23735
# Epoch 7/60
#  - 57s - loss: 0.2704 - acc: 0.8690 - val_loss: 0.2372 - val_acc: 0.8860
#
# Epoch 00007: val_loss improved from 0.23735 to 0.23718, saving model to bestWeights12.h5
# Epoch 8/60
#  - 57s - loss: 0.2686 - acc: 0.8700 - val_loss: 0.2348 - val_acc: 0.8863
#
# Epoch 00008: val_loss improved from 0.23718 to 0.23483, saving model to bestWeights12.h5
# Epoch 9/60
#  - 57s - loss: 0.2666 - acc: 0.8710 - val_loss: 0.2357 - val_acc: 0.8868
#
# Epoch 00009: val_loss did not improve from 0.23483
# Epoch 10/60
#  - 57s - loss: 0.2659 - acc: 0.8716 - val_loss: 0.2331 - val_acc: 0.8870
#
# Epoch 00010: val_loss improved from 0.23483 to 0.23306, saving model to bestWeights12.h5
# Epoch 11/60
#  - 57s - loss: 0.2652 - acc: 0.8720 - val_loss: 0.2429 - val_acc: 0.8863
#
# Epoch 00011: val_loss did not improve from 0.23306
# Epoch 12/60
#  - 57s - loss: 0.2632 - acc: 0.8728 - val_loss: 0.2358 - val_acc: 0.8877
#
# Epoch 00012: val_loss did not improve from 0.23306
# Epoch 13/60
#  - 57s - loss: 0.2615 - acc: 0.8738 - val_loss: 0.2327 - val_acc: 0.8881
#
# Epoch 00013: val_loss improved from 0.23306 to 0.23268, saving model to bestWeights12.h5
# Epoch 14/60
#  - 57s - loss: 0.2608 - acc: 0.8741 - val_loss: 0.2317 - val_acc: 0.8882
#
# Epoch 00014: val_loss improved from 0.23268 to 0.23172, saving model to bestWeights12.h5
# Epoch 15/60
#  - 57s - loss: 0.2603 - acc: 0.8745 - val_loss: 0.2309 - val_acc: 0.8881
#
# Epoch 00015: val_loss improved from 0.23172 to 0.23094, saving model to bestWeights12.h5
# Epoch 16/60
#  - 57s - loss: 0.2583 - acc: 0.8753 - val_loss: 0.2332 - val_acc: 0.8878
#
# Epoch 00016: val_loss did not improve from 0.23094
# Epoch 17/60
#  - 57s - loss: 0.2574 - acc: 0.8759 - val_loss: 0.2350 - val_acc: 0.8865
#
# Epoch 00017: val_loss did not improve from 0.23094
# Epoch 18/60
#  - 57s - loss: 0.2565 - acc: 0.8763 - val_loss: 0.2335 - val_acc: 0.8876
#
# Epoch 00018: val_loss did not improve from 0.23094
# Epoch 19/60
#  - 57s - loss: 0.2556 - acc: 0.8769 - val_loss: 0.2347 - val_acc: 0.8883
#
# Epoch 00019: val_loss did not improve from 0.23094
# Epoch 20/60
#  - 57s - loss: 0.2569 - acc: 0.8766 - val_loss: 0.2323 - val_acc: 0.8884
#
# Epoch 00020: val_loss did not improve from 0.23094
# Epoch 21/60
#  - 57s - loss: 0.2540 - acc: 0.8777 - val_loss: 0.2347 - val_acc: 0.8869
#
# Epoch 00021: val_loss did not improve from 0.23094
# Epoch 22/60
#  - 56s - loss: 0.2537 - acc: 0.8778 - val_loss: 0.2315 - val_acc: 0.8872
#
# Epoch 00022: val_loss did not improve from 0.23094
# Epoch 23/60
#  - 57s - loss: 0.2526 - acc: 0.8785 - val_loss: 0.2353 - val_acc: 0.8856
#
# Epoch 00023: val_loss did not improve from 0.23094
# Epoch 24/60
#  - 56s - loss: 0.2520 - acc: 0.8787 - val_loss: 0.2337 - val_acc: 0.8876
#
# Epoch 00024: val_loss did not improve from 0.23094
# Epoch 25/60
#  - 56s - loss: 0.2514 - acc: 0.8790 - val_loss: 0.2322 - val_acc: 0.8881
#
# Epoch 00025: val_loss did not improve from 0.23094
# Epoch 26/60
#  - 56s - loss: 0.2507 - acc: 0.8794 - val_loss: 0.2353 - val_acc: 0.8868
#
# Epoch 00026: val_loss did not improve from 0.23094
# Epoch 27/60
#  - 56s - loss: 0.2499 - acc: 0.8797 - val_loss: 0.2688 - val_acc: 0.8856
#
# Epoch 00027: val_loss did not improve from 0.23094
# Epoch 28/60
#  - 56s - loss: 0.2496 - acc: 0.8800 - val_loss: 0.2327 - val_acc: 0.8883
#
# Epoch 00028: val_loss did not improve from 0.23094
# Epoch 29/60
#  - 56s - loss: 0.2489 - acc: 0.8804 - val_loss: 0.2329 - val_acc: 0.8876
#
# Epoch 00029: val_loss did not improve from 0.23094
# Epoch 30/60
#  - 56s - loss: 0.2484 - acc: 0.8807 - val_loss: 0.2348 - val_acc: 0.8889
#
# Epoch 00030: val_loss did not improve from 0.23094
# Epoch 31/60
#  - 56s - loss: 0.2477 - acc: 0.8810 - val_loss: 0.2366 - val_acc: 0.8881
#
# Epoch 00031: val_loss did not improve from 0.23094
# Epoch 32/60
#  - 56s - loss: 0.2473 - acc: 0.8812 - val_loss: 0.2378 - val_acc: 0.8880
#
# Epoch 00032: val_loss did not improve from 0.23094
# Epoch 33/60
#  - 56s - loss: 0.2470 - acc: 0.8814 - val_loss: 0.2361 - val_acc: 0.8870
#
# Epoch 00033: val_loss did not improve from 0.23094
# Epoch 34/60
#  - 56s - loss: 0.2464 - acc: 0.8818 - val_loss: 0.2329 - val_acc: 0.8883
#
# Epoch 00034: val_loss did not improve from 0.23094
# Epoch 35/60
#  - 56s - loss: 0.2460 - acc: 0.8820 - val_loss: 0.2384 - val_acc: 0.8867
#
# Epoch 00035: val_loss did not improve from 0.23094
# Epoch 36/60
#  - 56s - loss: 0.2456 - acc: 0.8823 - val_loss: 0.2355 - val_acc: 0.8877
#
# Epoch 00036: val_loss did not improve from 0.23094
# Epoch 37/60
#  - 56s - loss: 0.2450 - acc: 0.8825 - val_loss: 0.2371 - val_acc: 0.8883
#
# Epoch 00037: val_loss did not improve from 0.23094
# Epoch 38/60
#  - 56s - loss: 0.2446 - acc: 0.8828 - val_loss: 0.2371 - val_acc: 0.8840
#
# Epoch 00038: val_loss did not improve from 0.23094
# Epoch 39/60
#  - 56s - loss: 0.2442 - acc: 0.8829 - val_loss: 0.2344 - val_acc: 0.8878
#
# Epoch 00039: val_loss did not improve from 0.23094
# Epoch 40/60
#  - 56s - loss: 0.2437 - acc: 0.8832 - val_loss: 0.2347 - val_acc: 0.8869
#
# Epoch 00040: val_loss did not improve from 0.23094
# Epoch 41/60
#  - 56s - loss: 0.2433 - acc: 0.8834 - val_loss: 0.2355 - val_acc: 0.8861
#
# Epoch 00041: val_loss did not improve from 0.23094
# Epoch 42/60
#  - 56s - loss: 0.2428 - acc: 0.8837 - val_loss: 0.2366 - val_acc: 0.8875
#
# Epoch 00042: val_loss did not improve from 0.23094
# Epoch 43/60
#  - 56s - loss: 0.2423 - acc: 0.8838 - val_loss: 0.2375 - val_acc: 0.8879
#
# Epoch 00043: val_loss did not improve from 0.23094
# Epoch 44/60
#  - 57s - loss: 0.2421 - acc: 0.8840 - val_loss: 0.2381 - val_acc: 0.8879
#
# Epoch 00044: val_loss did not improve from 0.23094
# Epoch 45/60
#  - 58s - loss: 0.2417 - acc: 0.8842 - val_loss: 0.2368 - val_acc: 0.8872
#
# Epoch 00045: val_loss did not improve from 0.23094
# Epoch 46/60
#  - 58s - loss: 0.2417 - acc: 0.8843 - val_loss: 0.2372 - val_acc: 0.8882
#
# Epoch 00046: val_loss did not improve from 0.23094
# Epoch 47/60
#  - 58s - loss: 0.2414 - acc: 0.8844 - val_loss: 0.2379 - val_acc: 0.8862
#
# Epoch 00047: val_loss did not improve from 0.23094
# Epoch 48/60
#  - 58s - loss: 0.2413 - acc: 0.8846 - val_loss: 0.2376 - val_acc: 0.8876
#
# Epoch 00048: val_loss did not improve from 0.23094
# Epoch 49/60
#  - 58s - loss: 0.2405 - acc: 0.8849 - val_loss: 0.2420 - val_acc: 0.8876
#
# Epoch 00049: val_loss did not improve from 0.23094
# Epoch 50/60
#  - 58s - loss: 0.2403 - acc: 0.8850 - val_loss: 0.2392 - val_acc: 0.8875
#
# Epoch 00050: val_loss did not improve from 0.23094
# Epoch 51/60
#  - 58s - loss: 0.2398 - acc: 0.8852 - val_loss: 0.2371 - val_acc: 0.8871
#
# Epoch 00051: val_loss did not improve from 0.23094
# Epoch 52/60
#  - 58s - loss: 0.2398 - acc: 0.8853 - val_loss: 0.2368 - val_acc: 0.8872
#
# Epoch 00052: val_loss did not improve from 0.23094
# Epoch 53/60
#  - 58s - loss: 0.2390 - acc: 0.8856 - val_loss: 0.2379 - val_acc: 0.8873
#
# Epoch 00053: val_loss did not improve from 0.23094
# Epoch 54/60
#  - 58s - loss: 0.2392 - acc: 0.8856 - val_loss: 0.2375 - val_acc: 0.8870
#
# Epoch 00054: val_loss did not improve from 0.23094
# Epoch 55/60
#  - 58s - loss: 0.2389 - acc: 0.8858 - val_loss: 0.2385 - val_acc: 0.8859
#
# Epoch 00055: val_loss did not improve from 0.23094
# Epoch 56/60
#  - 58s - loss: 0.2386 - acc: 0.8860 - val_loss: 0.2380 - val_acc: 0.8849
#
# Epoch 00056: val_loss did not improve from 0.23094
# Epoch 57/60
#  - 58s - loss: 0.2383 - acc: 0.8861 - val_loss: 0.2386 - val_acc: 0.8851
#
# Epoch 00057: val_loss did not improve from 0.23094
# Epoch 58/60
#  - 58s - loss: 0.2381 - acc: 0.8863 - val_loss: 0.2375 - val_acc: 0.8862
#
# Epoch 00058: val_loss did not improve from 0.23094
# Epoch 59/60
#  - 58s - loss: 0.2377 - acc: 0.8865 - val_loss: 0.2404 - val_acc: 0.8863
#
# Epoch 00059: val_loss did not improve from 0.23094
# Epoch 60/60
#  - 58s - loss: 0.2376 - acc: 0.8865 - val_loss: 0.2367 - val_acc: 0.8868
#
# Epoch 00060: val_loss did not improve from 0.23094
